# %% [markdown]
# # AES 128 BIT

# %%
import numpy as np
import time


sbox =  [   ]

reverse_sbox = [
            ]

rcon = [0x01, 0x02, 0x04, 0x08, 0x10, 0x20, 0x40, 0x80, 0x1B, 0x36]
fixedMat=np.array([['02', '03', '01' ,'01' ],['01' ,'02' ,'03' ,'01'],[ '01','01', '02' ,'03' ],['03', '01' ,'01' ,'02']])
inverse_fixedMat =np.array([['0E', '0B', '0D' ,'09' ],['09' ,'0E' ,'0B' ,'0D'],['0D' ,'09' ,'0E' ,'0B'],['0B' ,'0D' ,'09' ,'0E']])

def gfunc(w3,rNo):
  w3=np.roll(w3,-1,0)  #rotword

  for i in range(w3.size):  #sbox
    w3[i]=hex(sbox[(int(w3[i][0],16)*16)+int(w3[i][1],16)])[2:]
    if(len(w3[i])==1):  # pads with 0 if needed
      w3[i]='0'+w3[i]
    
  w3[0]=hex(int(bin(rcon[rNo]^int(w3[0],16)),2))[2:] #rcon

  return w3
#
def xor(w0,w1): #xor w0 and w1
  w2=w0.copy()
  for i in range(w0.size):
    w2[i]=hex(int(bin(int(w0[i],16)^int(w1[i],16)),2))[2:]
    if(len(w2[i])==1):# pads with 0 if needed
      w2[i]='0'+w2[i]

  return w2


def toMat(text):
  chunks = [text[i:i+2] for i in range(0, len(text), 2)]  # converting key into chunks of 2 bytes
  mat = np.array(chunks)  #converting chunks into np.array
  mat=mat.reshape(4,4).transpose()  #reshaping np.array and transposing
  return mat 

def gfMultiplication(v1, v2):
    GF_RANGE = 8; # GF^8
    
    #converting the hex values to integer
    v1 = int(v1, 16)
    v2 = int(v2, 16)
    
    # p will hold the product of v1 and v2
    prod = 0
    for i in range(GF_RANGE):
        if v2 & 1: prod ^= v1
        flag = v1 & 0x80
        v1 <<= 1
        # keep a 8 bit
        v1 &= 0xFF
        if flag:
            # taking XOR with irreducible polynomial 
            v1 ^= 0x1b
        v2 >>= 1
    return prod

def subKeyGen(key):
  print("Key Generation:")
  print("---------------")
  print("Provided key: " +key+"\n")

  subkeys=[]
  subkeys.append(key)
  mat=toMat(key)  #convert key into word matrix of 4,4 shape
  print("Key in form of Matrix:")
  print(mat)
  print(" ")

  print("Starting Rounds for generation:\n")
  for rn in range(10):

    print("Round "+str(rn+1)+":\n")
    newMat=mat.copy() 
    newMat[:,0]=xor(mat[:,0],gfunc(mat[:,3],rn))  #getting  first word of next matrix
    for i in range(3):
      newMat[:,i+1]=xor(mat[:,i+1],newMat[:,i+0])  #getting other words
    subK=""
    print("Key:\n")
    print(newMat)
    print(" ")

    mat=newMat.copy()
    newMat=newMat.transpose()    
    num_rows, num_cols = newMat.shape
    for x in range(num_rows):
      for y in range(num_cols):
        subK+=newMat[x][y]  #generate subkey
    subkeys.append(subK)  #appending subkeys
  return subkeys

def mixCol(row,col):
  x=[]
  for i in range(4):
    x.append(hex(gfMultiplication(row[i],col[i]))[2:])

  y=x[0]

  for i in range(3):
    z=hex(int(bin(int(y,16)^int(x[i+1],16)),2))[2:] #xor
    if(len(z)==1):# pads with 0 if needed
      z='0'+z
    y=z
  return y





def encrypt(subkeys,plainText):

  print("Encryption: ")
  print("---------------")
  print("Provided plainText: " +plainText+"\n")
  mat=toMat(plainText)  #convert plainText into word matrix of 4,4 shape
  num_rows, num_cols = mat.shape
  key1=toMat(subkeys[0]) # add key 0 round key

  for i in range(num_rows):   
    for j in range(num_cols):
      mat[i][j]=hex(int(bin(int(key1[i][j],16)^int(mat[i][j],16)),2))[2:]
      if(len(mat[i][j])==1):# pads with 0 if needed
        mat[i][j]='0'+mat[i][j]

  for rn in range(10):  # loop for all rounds
    
    print("Round "+str(rn+1)+":\n")
    for j in range(num_cols):   #sbox
      for i in range(num_rows):  
        mat[:,j][i]=hex(sbox[(int(mat[:,j][i][0],16)*16)+int(mat[:,j][i][1],16)])[2:]
        if(len(mat[:,j][i])==1):  # pads with 0 if needed
          mat[:,j][i]='0'+mat[:,j][i]

    for j in range(num_rows):   #shift rows
        mat[j]=np.roll(mat[j],0-j,0)
    newMat=mat.copy()
    if(rn!=9):

      for i in range(num_rows):       # mix volumn operation 
        for j in range(num_cols):
          newMat[i][j]=mixCol(fixedMat[i],mat[:,j])
    key=toMat(subkeys[rn+1]) # add round key

    for i in range(num_rows):   
      for j in range(num_cols):
        mat[i][j]=hex(int(bin(int(key[i][j],16)^int(newMat[i][j],16)),2))[2:]
        if(len(mat[i][j])==1):# pads with 0 if needed
          mat[i][j]='0'+mat[i][j]
    print("Cipher:\n")
    print(mat)
    print(" ")     
  mat=mat.transpose()
  cipher=""
  for x in range(num_rows):
    for y in range(num_cols):
      cipher+=mat[x][y]  #generate cipher
  f = open("cipher.enc", "w")
  f.write(cipher)
  f.close()

  return cipher

def decrypt(subkeys,cipher):

  print("Decryption: ")
  print("---------------")
  print("Cipher to decrypt: " + cipher +"\n")
  mat=toMat(cipher)  #convert plainText into word matrix of 4,4 shape
  num_rows, num_cols = mat.shape
  key_idx = len(subkeys) - 1
  key10 = toMat(subkeys[key_idx]) # add key 10 round key
  key_idx -= 1
    
    # add round key 
  for i in range(num_rows):   
    for j in range(num_cols):
      mat[i][j]=hex(int(bin(int(key10[i][j],16)^int(mat[i][j],16)),2))[2:]
      if(len(mat[i][j])==1):# pads with 0 if needed
        mat[i][j]='0'+mat[i][j]
  print("Matrix before rounds: ")
  print(mat)

  for rn in range(10):  # loop for all rounds
    print("Round "+str(rn+1)+":\n")
    
    for j in range(num_rows):   #shift rows
        mat[j]=np.roll(mat[j],0+j,0)
    print("After shift rows: ")
    print(mat)
    
    for j in range(num_cols):   #sbox
      for i in range(num_rows):  
        mat[:,j][i]=hex(reverse_sbox[(int(mat[:,j][i][0],16)*16)+int(mat[:,j][i][1],16)])[2:]
        if(len(mat[:,j][i])==1):  # pads with 0 if needed
          mat[:,j][i]='0'+mat[:,j][i]     
    print("After sbox: ")
    print(mat)
    
    newMat=mat.copy()
    key=toMat(subkeys[key_idx]) # add round key
    key_idx -= 1
    print("Key used: ")
    print(key)
    for i in range(num_rows):   
      for j in range(num_cols):
        mat[i][j]=hex(int(bin(int(key[i][j],16)^int(newMat[i][j],16)),2))[2:]
        if(len(mat[i][j])==1):# pads with 0 if needed
          mat[i][j]='0'+mat[i][j]
    print("After round key: ")
    print(mat)
    
    if(rn!=9):
      for i in range(num_rows):       # inverse mix volumn operation 
        for j in range(num_cols):
          newMat[i][j]=mixCol(inverse_fixedMat[i],mat[:,j])
      print("After mix column: ")
      mat = newMat
      print(mat)
        
    
    print("Plain Text:\n")
    print(mat)
    print(" ")     
  mat=mat.transpose()
  pt=""
  for x in range(num_rows):
    for y in range(num_cols):
      pt+=mat[x][y]  #generate cipher
  f = open("pt.dec", "w")
  f.write(pt)
  f.close()
  return pt



plainText="00000000000000000000000000000000"
f = open("EncryptionKey.key", "r")
keyInHex=f.read()

subkeys=subKeyGen(keyInHex)

start_time = time.time()
encryptedText=encrypt(subkeys,plainText)
enc_time = time.time() - start_time

start_time = time.time()
decryptedText = decrypt(subkeys, encryptedText)
dec_time = time.time() - start_time

print("Final Cipher:")
print(encryptedText)
print("Time taken in seconds for encryption: ", enc_time)

print("Decrypted Plain Text:")
print(decryptedText)
print("Time taken in seconds for decryption: ", dec_time)
# Out:
# Key Generation:
# ---------------
# Provided key: 00000000000000000000000000000000
#
# Key in form of Matrix:
# [['00' '00' '00' '00']
#  ['00' '00' '00' '00']
#  ['00' '00' '00' '00']
#  ['00' '00' '00' '00']]
#
# Starting Rounds for generation:
#
# Round 1:
#
# Key:
#
# [['62' '62' '62' '62']
#  ['63' '63' '63' '63']
#  ['63' '63' '63' '63']
#  ['63' '63' '63' '63']]
#
# Round 2:
#
# Key:
#
# [['9b' 'f9' '9b' 'f9']
#  ['98' 'fb' '98' 'fb']
#  ['98' 'fb' '98' 'fb']
#  ['c9' 'aa' 'c9' 'aa']]
#
# Round 3:
#
# Key:
#
# [['90' '69' 'f2' '0b']
#  ['97' '6c' 'f4' '0f']
#  ['34' 'cf' '57' 'ac']
#  ['50' 'fa' '33' '99']]
#
# Round 4:
#
# Key:
#
# [['ee' '87' '75' '7e']
#  ['06' '6a' '9e' '91']
#  ['da' '15' '42' 'ee']
#  ['7b' '81' 'b2' '2b']]
#
# Round 5:
#
# Key:
#
# [['7f' 'f8' '8d' 'f3']
#  ['2e' '44' 'da' '4b']
#  ['2b' '3e' '7c' '92']
#  ['88' '09' 'bb' '90']]
#
# Round 6:
#
# Key:
#
# [['ec' '14' '99' '6a']
#  ['61' '25' 'ff' 'b4']
#  ['4b' '75' '09' '9b']
#  ['85' '8c' '37' 'a7']]
# ...
